# %% [markdown]
# # General Interference
# Here is a couple sin waves to play with and combine!

# %%
# %matplotlib notebook
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.widgets import Slider
import numpy as np

def func(x_, a_, w_):
    return np.exp(-a_ * (x_ - 5)**2) * np.cos(w_ * x_)

x_list = np.linspace(0, 10, 1000)
lb_a = 0.1
ub_a = 10.0
a_bounds = (lb_a, ub_a)
a0 = (lb_a + ub_a) / 2

lb_w = -5.0
ub_w = 20.0
w_bounds = (lb_w, ub_w)
w0 = (lb_w + ub_w) / 2

# General plot parameters
mpl.rcParams['font.size'] = 18

mpl.rcParams['axes.linewidth'] = 2
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False

mpl.rcParams['xtick.major.size'] = 10
mpl.rcParams['xtick.major.width'] = 2
mpl.rcParams['ytick.major.size'] = 10
mpl.rcParams['ytick.major.width'] = 2

fig = plt.figure(figsize=(8, 6))

# Create main axis
ax = fig.add_subplot(111)
ax.set(xlim=(0, 10), ylim=(-1, 1))
fig.subplots_adjust(bottom=0.2, top=0.80)

ax_a = fig.add_axes([0.15, 0.85, 0.75, 0.05])
ax_a.spines['top'].set_visible(True)
ax_a.spines['right'].set_visible(True)

ax_w = fig.add_axes([0.15, 0.92, 0.75, 0.05])
ax_w.spines['top'].set_visible(True)
ax_w.spines['right'].set_visible(True)

s_a = Slider(ax=ax_a, label='width', valmin=lb_a, valmax=ub_a, valinit=a0, valfmt=' %1.1f', facecolor='#cc7000')
s_w = Slider(ax=ax_w, label='$\omega$', valmin=lb_w, valmax=ub_w, valinit=w0, valfmt=' %i', facecolor='#cc7000')


graph = ax.plot(x_list, func(x_list, a0, w0), 'C0')[0]

# Update values
def update(val):
    a = s_a.val
    w = s_w.val
    graph.set_data(x_list, func(x_list, a, w))
    fig.canvas.draw_idle()

s_a.on_changed(update)
s_w.on_changed(update)


plt.show()
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def sin(x_, w_, d_):
    return np.sin(w_ * x_ + d_)

x_list = np.linspace(0, 10, 1000)

lb_d1 = -3.14 * 5
ub_d1 = 3.15 * 5
d1_bounds = (lb_d1, ub_d1)
d10 = (lb_d1 + ub_d1) / 2

lb_d2 = -3.14 * 5
ub_d2 = 3.15 * 5
d2_bounds = (lb_d2, ub_d2)
d20 = (lb_d2 + ub_d2) / 2

lb_w1 = 0
ub_w1 = 20.0
w1_bounds = (lb_w1, ub_w1)
w10 = (lb_w1 + ub_w1) / 2

lb_w2 = 0
ub_w2 = 20.0
w2_bounds = (lb_w2, ub_w2)
w20 = (lb_w2 + ub_w2) / 2

# General plot parameters
mpl.rcParams['font.size'] = 18

mpl.rcParams['axes.linewidth'] = 2
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False

mpl.rcParams['xtick.major.size'] = 10
mpl.rcParams['xtick.major.width'] = 2
mpl.rcParams['ytick.major.size'] = 10
mpl.rcParams['ytick.major.width'] = 2

#fig1 = plt.figure(figsize=(8, 6))


#ax1 = fig1.add_subplot(111)
fig1, ax = plt.subplots(3, 1)
fig1.set_size_inches(6, 8)

ax1 = ax[0]
ax2 = ax[1]
ax3 = ax[2]

ax1.set(xlim=(0, 10), ylim=(-2, 2))
ax2.set(xlim=(0, 10), ylim=(-2, 2))
ax3.set(xlim=(0, 10), ylim=(-2.2, 2.2))

fig1.subplots_adjust(bottom=0.2, top=0.70)

slider_bar_height = 0.05
sbh = slider_bar_height
slider_bar_width  = 0.75
sbw = slider_bar_width

top_axes_bottom_y = 0.9
taby = top_axes_bottom_y

# add_axes(left point x, bottom point y, width, height)
ax_w1 = fig1.add_axes([0.15, taby, slider_bar_width, slider_bar_height])
ax_w1.spines['top'].set_visible(True)
ax_w1.spines['right'].set_visible(True)

ax_d1 = fig1.add_axes([0.15, taby - sbh, slider_bar_width, slider_bar_height])
ax_d1.spines['top'].set_visible(True)
ax_d1.spines['right'].set_visible(True)

ax_w2 = fig1.add_axes([0.15, taby - 2*sbh, slider_bar_width, slider_bar_height])
ax_w2.spines['top'].set_visible(True)
ax_w2.spines['right'].set_visible(True)

ax_d2 = fig1.add_axes([0.15, taby - 3*sbh, slider_bar_width, slider_bar_height])
ax_d2.spines['top'].set_visible(True)
ax_d2.spines['right'].set_visible(True)


s_d1 = Slider(ax=ax_d1, label='$\delta$1', valmin=lb_d1, valmax=ub_d1, valinit=d10, valfmt=' %1.1f', facecolor='#cc7000')
s_w1 = Slider(ax=ax_w1, label='$\omega$1', valmin=lb_w1, valmax=ub_w1, valinit=w10, valfmt=' %i', facecolor='#cc7000')
s_d2 = Slider(ax=ax_d2, label='$\delta$2', valmin=lb_d2, valmax=ub_d2, valinit=d20, valfmt=' %1.1f', facecolor='#cc7000')
s_w2 = Slider(ax=ax_w2, label='$\omega$2', valmin=lb_w2, valmax=ub_w2, valinit=w20, valfmt=' %i', facecolor='#cc7000')

y10 = sin(x_list, w10, d10)
y20 = sin(x_list, w20, d20)
y30 = y10 + y20
graph1 = ax1.plot(x_list, y10, 'C0')[0]
graph2 = ax2.plot(x_list, y20, 'C0')[0]
graph3 = ax3.plot(x_list, y30, 'C0')[0]

# Update values
def update(val):
    d1 = s_d1.val
    w1 = s_w1.val
    d2 = s_d2.val
    w2 = s_w2.val
    y1 = sin(x_list, w1, d1)
    y2 = sin(x_list, w2, d2)
    y3 = y1 + y2
    graph1.set_ydata(y1)
    graph2.set_ydata(y2)
    graph3.set_ydata(y3)
    fig1.canvas.draw_idle()

s_d1.on_changed(update)
s_w1.on_changed(update)
s_d2.on_changed(update)
s_w2.on_changed(update)

plt.subplots_adjust(hspace=0.4)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # THE MICHELSON INTERFEROMETER
#
# This is my project on the Michelson interferometer. It presents two situations via python scripts with interactivity and plotting via matplotlib. It also includes a basic demo with general interference. I hope you enjoy this and hope it is worth your time

# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
from scipy.constants import pi
from matplotlib.widgets import Slider


w0 = 0.02
L = 0.10
lambda_ = 540e-9
k = 2 * pi / lambda_
I0 = 1
d0 = 1e-6
d_min, d_max = (1.25e-5, 1.5e-5)

def Delta_p(theta, d=d0):
    return 2 * d * np.cos(theta)

def I(theta, _lambda, d=d0, I0=1):
    Delta_r = _lambda / 2
    Delta = Delta_r + Delta_p(theta, d)
    _delta = k * Delta
    I = 4 * I0 * np.cos(_delta / 2)**2
    return I

angular_range = 2 * np.arctan(w0 / L)
theta = np.linspace(-angular_range, angular_range, 500)
THETA_x, THETA_y = np.meshgrid(theta, theta)
THETA = np.sqrt(THETA_x**2 + THETA_y**2)
I_ = I(THETA, lambda_)
#print(I_)

fig = plt.figure(figsize=(8,6), constrained_layout=True)

gs = plt.GridSpec(10, 2, figure=fig)
ax1 = fig.add_subplot(gs[0, :])
ax2 = fig.add_subplot(gs[1:, :])
text = ax2.text(0, 0, "", va="bottom", ha="left")

ax1.spines['top'].set_visible(True)
ax1.spines['right'].set_visible(True)
d_slider = Slider(ax=ax1, label='d', valmin=d_min, valmax=d_max, valinit=d0, valfmt=' %2.1e', facecolor='#cc7000')


color_norm = plt.Normalize(0, 4)
#fig.colorbar(im, cax=ax2, orientation='vertical')
im  = ax2.imshow(I_, cmap=plt.cm.gist_gray, norm=color_norm)


def update(val):
    d_ = d_slider.val
    I_ = I(THETA, lambda_, d=d_)
    im.set_data(I_)
    fig.canvas.draw_idle()

d_slider.on_changed(update)
d_step = (d_max - d_min) / 100
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # THE RANGE
#
# This simulation is *slightly* different just due to the fact that it does not use a totally monocromatic source! This simulation takes into account the spectrum of wavelengths in  many sources. I use the same method from before, but this time sample several wavelengths and combine them, assuming their irradiances add linearly

# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
from scipy.constants import pi
from matplotlib.widgets import Slider


w0 = 0.005
L = 0.10
lambda_ = 500e-9
lambda_min, lambda_max = (588e-9, 589e-9)
lambda_min, lambda_max = (380e-9, 700e-9)
lambda_range = np.linspace(lambda_min, lambda_max, 50)
#lambda_range = np.array([lambda_])
k_range = 2 * pi / lambda_range
#k = 2 * pi / lambda_
I0 = 1
d0 = 4e-6
d_min, d_max = (1.25e-5, 1.5e-5)
d0 = d_min

def Delta_p(theta, d=d0):
    return 2 * d * np.cos(theta)

def I(theta, _lambda, d=d0, I0=1):
    Delta_r = _lambda / 2
    Delta = Delta_r + Delta_p(theta, d)
    k = 2 * pi / lambda_
    _delta = k * Delta
    I = 4 * I0 * np.cos(_delta / 2)**2
    return I

def I_true(lambda_list):
    def func(theta, d):
        N = len(lambda_list)
        return np.array(np.sum([I(theta, lambda_val, d) / N for lambda_val in lambda_list], 0))
    return func

angular_range = 2 * np.arctan(w0 / L)
theta = np.linspace(-angular_range, angular_range, 100)
THETA_x, THETA_y = np.meshgrid(theta, theta)
THETA = np.sqrt(THETA_x**2 + THETA_y**2)
I_profile = I_true(lambda_range)
I_ = I_profile(THETA, d0)

fig = plt.figure(figsize=(8,6), constrained_layout=True)

gs = plt.GridSpec(10, 2, figure=fig)
ax1 = fig.add_subplot(gs[0, :])
ax2 = fig.add_subplot(gs[1:, :])
text = ax2.text(0, 0, "", va="bottom", ha="left")

ax1.spines['top'].set_visible(True)
ax1.spines['right'].set_visible(True)
d_slider = Slider(ax=ax1, label='d', valmin=d_min, valmax=d_max, valinit=d0, valfmt=' %2.1e', facecolor='#cc7000')


color_norm = plt.Normalize(0, 4)
#fig.colorbar(im, cax=ax2, orientation='vertical')
im  = ax2.imshow(I_, cmap=plt.cm.gist_gray, norm=color_norm)


def update(val):
    d_ = d_slider.val
    I_ = I_profile(THETA, d=d_)
    #I_ = I(THETA, lambda_, d_)
    im.set_data(I_)
    fig.canvas.draw_idle()
    #text.set_text("%f, %f" %(np.max(color_norm(I_)), np.min(color_norm(I_))))

d_slider.on_changed(update)
d_step = (d_max - d_min) / 100
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
